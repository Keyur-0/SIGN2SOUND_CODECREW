# %%
import os, sys
sys.path.append(os.path.abspath(".."))
os.chdir("..")

# %% [markdown]
# Import libs

# %%
import numpy as np
from preprocessing.extract_features import load_dataset

# %% [markdown]
# Load dataset

# %%
x, y, labels= load_dataset()
print(x.shape, y.shape)
# Out:
# (3000, 30, 63) (3000,)

# %% [markdown]
# Inpect one sample

# %%
x[0].shape
# Out:
# (30, 63)

# %% [markdown]
# Class distribution

# %%
from collections import Counter
Counter(y)
# Out:
# Counter({np.str_('A'): 120,
#          np.str_('B'): 120,
#          np.str_('C'): 120,
#          np.str_('D'): 120,
#          np.str_('E'): 120,
#          np.str_('F'): 120,
#          np.str_('G'): 120,
#          np.str_('H'): 120,
#          np.str_('I'): 120,
#          np.str_('J'): 120,
#          np.str_('K'): 120,
#          np.str_('L'): 120,
#          np.str_('M'): 120,
#          np.str_('N'): 120,
#          np.str_('O'): 120,
#          np.str_('P'): 120,
#          np.str_('Q'): 120,
#          np.str_('S'): 120,
#          np.str_('T'): 120,
#          np.str_('U'): 120,
#          np.str_('V'): 120,
#          np.str_('W'): 120,
#          np.str_('X'): 120,
#          np.str_('Y'): 120,
#          np.str_('Z'): 120})

# %% [markdown]
# Short markdown cell:
#
# Dataset consists of 3000 sequences, each of length 30 with 63 features per frame.
