# %% [markdown]
# Load Metrics

# %%
import json
with open("../results/metrics.json") as f:
    metrics = json.load(f)

# %% [markdown]
# Plot curves

# %%
import matplotlib.pyplot as plt

plt.plot(metrics["train_accuracy"], label="Train")
plt.plot(metrics["val_accuracy"], label="Validation")
plt.legend()
plt.title("Accuracy Curve")
# Out:
# Text(0.5, 1.0, 'Accuracy Curve')

# %% [markdown]
# Display confusion matrix

# %%
from PIL import Image
Image.open("../results/confusion_matrix.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x800>

# %% [markdown]
# Markdown summary:
#
# Model achieves ~75% validation accuracy with stable convergence.
